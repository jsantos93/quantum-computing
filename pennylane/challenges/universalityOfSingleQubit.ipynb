# %%
import json
import pennylane as qml
import pennylane.numpy as np

np.random.seed(1967)

def get_matrix(params):
    """
    Args:
        - params (array): The four parameters of the model.
        
    Returns:
        - (matrix): The associated matrix to these parameters.
    """


    alpha, beta, gamma, phi = params
    
    # Put your code here #
    rz_gamma = np.array([[np.exp(-1j* gamma/2), 0],[0, np.exp(1j*gamma/2)]])
    rx_beta = np.array([[np.cos(beta/2) , -1j*np.sin(beta/2)],[-1j*np.sin(beta/2), np.cos(beta/2)]])
    rz_alpha = np.array([[np.exp(-1j* alpha/2), 0],[0, np.exp(1j*alpha/2)]])
    
    u = np.exp(-1j*phi) * rz_gamma * rx_beta * rz_alpha
    # Return the matrix
    return u

def error(U, params):
    """
    This function determines the similarity between your generated matrix and
    the target unitary.

    Args:
        - U (np.array): Goal matrix that we want to approach.
        - params (array): The four parameters of the model.

    Returns:
        - (float): Error associated with the quality of the solution.
    """
    
    matrix = get_matrix(params)

    # Put your code here #
    normM = np.linalg.norm(matrix)
    normU = np.linalg.norm(U)
    print(f"Norma da matrix = {normM}")
    print(f"Norma U = {normU}")
    
    # Return the error
    return normU - normM

def train_parameters(U):
    epochs = 1000
    lr = 0.01

    grad = qml.grad(error, argnum=1)
    params = np.random.rand(4) * np.pi
    for epoch in range(epochs):
        params -= lr * grad(U, params)
    
    return params


# These functions are responsible for testing the solution.
def run(test_case_input: str) -> str:
    matrix = json.loads(test_case_input)
    params = [float(p) for p in train_parameters(matrix)]
    return json.dumps(params)


def check(solution_output: str, expected_output: str) -> None:
    matrix1 = get_matrix(json.loads(solution_output))
    matrix2 = json.loads(expected_output)
    assert not np.allclose(get_matrix(np.random.rand(4)), get_matrix(np.random.rand(4)))
    assert np.allclose(matrix1, matrix2, atol=0.2)


# These are the public test cases
test_cases = [
    ('[[ 0.70710678,  0.70710678], [ 0.70710678, -0.70710678]]', '[[ 0.70710678,  0.70710678], [ 0.70710678, -0.70710678]]'),
    ('[[ 1,  0], [ 0, -1]]', '[[ 1,  0], [ 0, -1]]')
]

# This will run the public test cases locally
for i, (input_, expected_output) in enumerate(test_cases):
    print(f"Running test case {i} with input '{input_}'...")

    try:
        output = run(input_)
        print(output)
        print(expected_output)

    except Exception as exc:
        print(f"Runtime Error. {exc}")

    else:
        if message := check(output, expected_output):
            print(f"Wrong Answer. Have: '{output}'. Want: '{expected_output}'.")

        else:
            print("Correct!")
# Out:
# Running test case 0 with input '[[ 0.70710678,  0.70710678], [ 0.70710678, -0.70710678]]'...
# Norma da matrix = Autograd ArrayBox with value 0.8788057795701812
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8799443434771663
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8811018931668302
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8822782824455109
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8834733613547576
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8846869761667634
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8859189693836771
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8871691797408789
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.888437442214299
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8897235880318393
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8910274446889622
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8923488359684902
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8936875819646534
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8950434991114148
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8964164002150916
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8978060944912791
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.8992123876060749
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.90063508172159
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9020739755457258
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9035288643861814
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9049995402086495
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9064857916991451
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9079874043304068
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9095041604322929
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9110358392660939
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.912582217102666
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9141430673042851
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9157181604101111
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.9173072642251446
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 0.
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4123754517898401
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4123884178161155
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4124012924389309
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.412414076301805
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4124267700437358
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.412439374299234
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4124518896983558
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4124643168667301
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4124766564255935
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.412488908991819
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4125010751779459
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4125131555922124
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.412525150838583
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4125370615167807
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4125488882223143
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4125606315465093
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4125722920765384
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4125838703954476
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4125953670821874
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4126067827116402
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.412618117854649
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4126293730780461
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4126405489446812
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.412651646013448
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4126626648393135
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4126736059733447
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4126844699627357
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4126952573508345
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4127059686771724
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.412716604477486
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4127271652837488
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4127376516241943
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.412748064023343
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.412758403002029
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4127686690774248
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4127788627630677
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4127889845688852
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4127990350012196
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128090145628538
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128189237530364
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128287630675052
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128385329985131
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128482340348518
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128578666618772
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128674313615313
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128769286123675
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128863588895746
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4128957226650003
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129050204071731
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129142525813285
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129234196494278
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129325220701854
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129415602990893
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129505347884235
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129594459872918
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129682943416388
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129770802942723
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129858042848868
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4129944667500822
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130030681233885
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130116088352864
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130200893132272
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.413028509981657
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130368712620343
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130451735728538
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130534173296654
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130616029450966
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130697308288707
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130778013878287
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4130858150259498
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.41309377214437
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131016731414037
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131095184125615
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131173083505724
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131250433454015
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131327237842692
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131403500516722
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131479225294006
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.413155441596558
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131629076295804
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131703210022546
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131776820857371
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131849912485714
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131922488567077
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4131994552735214
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132066108598293
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132137159739095
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132207709715179
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132277762059062
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.41323473202784
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132416387856161
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132484968250794
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.41325530648964
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132620681202912
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132687820556253
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132754486318522
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132820681828138
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132886410400018
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4132951675325753
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133016479873752
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133080827289417
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133144720795292
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133208163591255
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133271158854634
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.413333370974039
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133395819381278
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133457490887988
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133518727349317
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133579531832294
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133639907382376
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.413369985702356
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.413375938375855
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133818490568908
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.413387718041521
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133935456237168
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4133993320953797
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134050777463567
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134107828644518
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134164477354434
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.413422072643097
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134276578691802
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134332036934742
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134387103937924
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134441782459897
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134496075239789
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134549984997435
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134603514433508
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.4134656666229668
# Norma U = 1.41421356
# Norma da matrix = Autograd ArrayBox with value 1.413470944304868
# Norma U = 1.41421356
# [1.696867134049971, 0.06458792654498209, 1.444728001883675, 1.5707963267959995]
# [[ 0.70710678,  0.70710678], [ 0.70710678, -0.70710678]]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[52], line 97
#      94     print(f"Runtime Error. {exc}")
#      96 else:
# ---> 97     if message := check(output, expected_output):
#      98         print(f"Wrong Answer. Have: '{output}'. Want: '{expected_output}'.")
#     100     else:
#
# Cell In[52], line 75, in check(solution_output, expected_output)
#      73 matrix2 = json.loads(expected_output)
#      74 assert not np.allclose(get_matrix(np.random.rand(4)), get_matrix(np.random.rand(4)))
# ---> 75 assert np.allclose(matrix1, matrix2, atol=0.2)
#
# AssertionError:

# %%
gamma = 0.70
rz_gamma = np.array([[np.exp(-1j* (gamma/2)), 0],[0, np.exp(1j*gamma/2)]])
print(rz_gamma)
# Out:
# [[0.93937271-0.34289781j 0.        +0.j        ]
#  [0.        +0.j         0.93937271+0.34289781j]]
